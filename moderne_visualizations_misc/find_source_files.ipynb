# %%
from code_data_science import data_table as dt, data_grid as moderne_data_grid

df = dt.read_csv('../samples/find_source_files.csv')

# %%
df['LST Type'] = 1
df
# Out:
#      repositoryOrigin              repositoryPath repositoryBranch  \
# 0          github.com  svok/kotlin-jar2npm-plugin           master
# 1          github.com  svok/kotlin-jar2npm-plugin           master
# 2          github.com  svok/kotlin-jar2npm-plugin           master
# 3          github.com  svok/kotlin-jar2npm-plugin           master
# 4          github.com               melix/jdoctor             main
# ...               ...                         ...              ...
# 6899       github.com     moevm/adfmp20-caller-id           master
# 6900       github.com     moevm/adfmp20-caller-id           master
# 6901       github.com     moevm/adfmp20-caller-id           master
# 6902       github.com     moevm/adfmp20-caller-id           master
# 6903       github.com     moevm/adfmp20-caller-id           master
#
#                                              sourcePath             type  \
# 0     jar2npm-plugin/src/main/kotlin/com/crowdproj/p...  CompilationUnit
# 1     jar2npm-plugin/src/main/kotlin/com/crowdproj/p...  CompilationUnit
# 2     jar2npm-plugin/src/main/kotlin/com/crowdproj/p...  CompilationUnit
# 3     jar2npm-plugin/src/test/kotlin/com/crowdproj/p...  CompilationUnit
# 4     jdoctor-build-logic/src/main/kotlin/me/champea...            Quark
# ...                                                 ...              ...
# 6899  app/src/main/java/com/leti/phonedetector/MainA...            Quark
# 6900  app/src/main/java/com/leti/phonedetector/searc...            Quark
# 6901  app/src/main/java/com/leti/phonedetector/Stati...            Quark
# 6902  app/src/main/java/com/leti/phonedetector/conta...            Quark
# 6903  app/src/androidTest/java/com/leti/phonedetecto...            Quark
#
#       LST Type
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1
# ...        ...
# 6899         1
# 6900         1
# 6901         1
# 6902         1
# 6903         1
#
# [6904 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
from code_data_science import palette as colors

df.groupby(['type']).sum().plot(kind='barh', y='LST Type',color=colors.qualitative())
plt.show()
