# %%
from moderne_visualizations_misc.reusable.data_loader import read_data_table
from code_data_science import data_table as dt, data_grid as moderne_data_grid

# df = read_data_table("../samples/effective_maven_settings.csv")
df = read_data_table("../samples/v2/org.openrewrite.maven.table.EffectiveMavenSettings.csv")

# %%
df

# %%
moderne_data_grid.display(df)
